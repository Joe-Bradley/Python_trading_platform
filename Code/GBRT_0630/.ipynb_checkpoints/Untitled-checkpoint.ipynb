# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sTicker_lis =  ['3443','2388', '2498', '2610', '1319', '3035', '3006', '2615', '5425', '3105']
def dff(ticker):  
    a = pd.read_csv(ticker + '.csv')
    del a['Unnamed: 0']
    a = a[['return', 'time']]
    a.set_index('time', inplace = True)
    a.rename(columns={'return': ticker},inplace = True)
    return a

# %%
for i in range(len(sTicker_lis)):
    df = dff(sTicker_lis[i])
    if i == 0:
        total_df = df
    else:
        total_df = pd.merge(total_df, df, left_index=True, right_index=True, how='outer').fillna(method = 'ffill')

# %%
total_df.index = pd.to_datetime(total_df.index).strftime('%H:%M')

# %%
total_df.describe()
# Out:
#                 3443           2388           2498           2610  \
# count  155064.000000  155064.000000  155064.000000  155064.000000
# mean       -0.041858       0.003541       0.002093      -0.007091
# std         0.014311       0.005204       0.002491       0.004725
# min        -0.053750      -0.006205      -0.002835      -0.015052
# 25%        -0.048750      -0.001865       0.000015      -0.011150
# 50%        -0.048000       0.004335       0.001425      -0.006027
# 75%        -0.043750       0.008675       0.004405      -0.002777
# max         0.008000       0.013635       0.007965       0.006847
#
#                 1319           3035           3006           2615  \
# count  155064.000000  155064.000000  155064.000000  155064.000000
# mean        0.002949      -0.001078       0.003506      -0.019388
# std         0.002249       0.006068       0.002415       0.006830
# min        -0.002020      -0.021150      -0.000095      -0.036540
# 25%         0.000950      -0.004700       0.001230      -0.022940
# 50%         0.002860       0.000000       0.003615      -0.021580
# 75%         0.004770       0.002350       0.004825      -0.015180
# max         0.008590       0.016450       0.009665       0.000900
#
#                 5425           3105
# count  155064.000000  155064.000000
# mean       -0.006261      -0.006385
# std         0.003264       0.002141
# min        -0.010665      -0.008225
# 25%        -0.008460      -0.007550
# 50%        -0.007430      -0.007350
# 75%        -0.005735      -0.006750
# max         0.000635       0.000000

# %%
ax = total_df.plot()


ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
